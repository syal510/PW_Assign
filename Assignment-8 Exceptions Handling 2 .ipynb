# %% [markdown]
# ## Exceptions Handling - 2

# %% [markdown]
# **Q1. Explain why we have to use the Exception class while creating a Custom Exception.**

# %% [markdown]
# Exception class is required while creating custom exceptions to handle runtime error or exceptions that may happend during the execution of the program.

# %% [markdown]
# **Q2. Write a python program to print Python Exception Hierarchy.**

# %%
def print_exception_hierarchy(exception_class, indent = 0):
    print(" "*indent, exception_class.__name__)
    for subclass in exception_class.__subclasses__():
        print_exception_hierarchy(subclass, indent + 4)
print_exception_hierarchy(BaseException)
# Out:
#  BaseException
#      Exception
#          TypeError
#              FloatOperation
#              MultipartConversionError
#          StopAsyncIteration
#          StopIteration
#          ImportError
#              ModuleNotFoundError
#              ZipImportError
#          OSError
#              ConnectionError
#                  BrokenPipeError
#                  ConnectionAbortedError
#                  ConnectionRefusedError
#                  ConnectionResetError
#                      RemoteDisconnected
#              BlockingIOError
#              ChildProcessError
#              FileExistsError
#              FileNotFoundError
#              IsADirectoryError
#              NotADirectoryError
#              InterruptedError
#                  InterruptedSystemCall
#              PermissionError
#              ProcessLookupError
#              TimeoutError
#              UnsupportedOperation
#              itimer_error
#              herror
#              gaierror
# ...

# %% [markdown]
# **Q3. What errors are defined in the ArithmeticError class? Explain any two with an example.**

# %% [markdown]
# ArithmeticError includes following errors:<br>
# 1. FloatingPointError
# 2. OverflowError
# 3. ZeroDivisionError

# %% [markdown]
# **Q4. Why LookupError class is used? Explain with an example KeyError and IndexError.**

# %% [markdown]
# Lookup error class is used to handle the exceptions related to looking up the values e.g. in list or dictionary and retrieving the values. Examples of KeyError and IndexError are as follows

# %%
# KeyError
a = {'alpha':1, 'beta':2, 'gamma':3}
try:
    print(a['alphax'])
except KeyError as e:
    print('key error:', e)
# Out:
# key error: 'alphax'

# %%
# IndexError
a = [1,2,3,4,5,6]
try:
    print(a[9])
except IndexError as e:
    print('Index error:', e)
# Out:
# Index error: list index out of range

# %% [markdown]
# **Q5. Explain ImportError. What is ModuleNotFoundError?**

# %% [markdown]
# ImportError is raised when the import statement fails to find and load the specific module. ModelueNotFoundError is a subclass of ImportError which is raised when specific module is not available rather than some other import related issue.

# %% [markdown]
# **Q6. List down some best practices for exception handling in python.**

# %% [markdown]
# Below are the best practices in exception handling:
# 1. Be specific with the exception. Avoid using a general exceptions and catch only the exceptions which you exepct.
# 2. Use multiple excpet block for different exception types.
# 3. Use logging function to log exceptions rather than printing them out.
